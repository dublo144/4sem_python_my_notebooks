# %%
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt

re = requests.get('http://localhost:5000/api/manufactorcount')

json_dump = json.dumps(re.text)

df = pd.read_json(re.text)

pd.set_option("display.max.columns", None)
df.head()
df1 = df.iloc[0]
make = list(df.iloc[0])
count = list(df.iloc[1])
width = 1
plt.pie(count,labels=make)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8beb69e810>,
#   <matplotlib.patches.Wedge at 0x7f8beb69ec10>,
#   <matplotlib.patches.Wedge at 0x7f8beb6b12d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb6b1390>,
#   <matplotlib.patches.Wedge at 0x7f8beb6ba210>,
#   <matplotlib.patches.Wedge at 0x7f8beb6ba850>,
#   <matplotlib.patches.Wedge at 0x7f8beb6ba590>,
#   <matplotlib.patches.Wedge at 0x7f8beb6c5150>,
#   <matplotlib.patches.Wedge at 0x7f8beb6b1950>,
#   <matplotlib.patches.Wedge at 0x7f8beb6ba5d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb6e5550>,
#   <matplotlib.patches.Wedge at 0x7f8beb651250>,
#   <matplotlib.patches.Wedge at 0x7f8beb6517d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb65d2d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb65d390>,
#   <matplotlib.patches.Wedge at 0x7f8beb65d950>,
#   <matplotlib.patches.Wedge at 0x7f8beb667450>,
#   <matplotlib.patches.Wedge at 0x7f8beb667510>,
#   <matplotlib.patches.Wedge at 0x7f8beb667ad0>,
#   <matplotlib.patches.Wedge at 0x7f8beb6730d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb673690>,
#   <matplotlib.patches.Wedge at 0x7f8beb67e190>,
#   <matplotlib.patches.Wedge at 0x7f8beb67e250>,
#   <matplotlib.patches.Wedge at 0x7f8beb67e810>,
#   <matplotlib.patches.Wedge at 0x7f8beb689310>,
#   <matplotlib.patches.Wedge at 0x7f8beb6893d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb689990>,
#   <matplotlib.patches.Wedge at 0x7f8beb614490>,
#   <matplotlib.patches.Wedge at 0x7f8beb614550>,
#   <matplotlib.patches.Wedge at 0x7f8beb61f050>,
#   <matplotlib.patches.Wedge at 0x7f8beb61f110>,
#   <matplotlib.patches.Wedge at 0x7f8beb61f6d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb62b1d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb62b290>,
#   <matplotlib.patches.Wedge at 0x7f8beb62b850>,
#   <matplotlib.patches.Wedge at 0x7f8beb636350>,
#   <matplotlib.patches.Wedge at 0x7f8beb636410>,
#   <matplotlib.patches.Wedge at 0x7f8beb6369d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb6404d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb640590>,
#   <matplotlib.patches.Wedge at 0x7f8beb64c090>,
#   <matplotlib.patches.Wedge at 0x7f8beb64c150>,
#   <matplotlib.patches.Wedge at 0x7f8beb64c710>,
#   <matplotlib.patches.Wedge at 0x7f8beb5d7210>,
#   <matplotlib.patches.Wedge at 0x7f8beb5d72d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb5d7890>,
#   <matplotlib.patches.Wedge at 0x7f8beb5e2390>,
#   <matplotlib.patches.Wedge at 0x7f8beb5e2450>,
#   <matplotlib.patches.Wedge at 0x7f8beb5e2a10>,
#   <matplotlib.patches.Wedge at 0x7f8beb5f1510>,
#   <matplotlib.patches.Wedge at 0x7f8beb5f15d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb5f90d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb5f9190>,
#   <matplotlib.patches.Wedge at 0x7f8beb5f9750>,
#   <matplotlib.patches.Wedge at 0x7f8beb605250>,
#   <matplotlib.patches.Wedge at 0x7f8beb605310>,
#   <matplotlib.patches.Wedge at 0x7f8beb6058d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb5913d0>,
#   <matplotlib.patches.Wedge at 0x7f8beb591490>,
#   <matplotlib.patches.Wedge at 0x7f8beb591a50>,
#   <matplotlib.patches.Wedge at 0x7f8beb59d050>],
#  [Text(1.0029451487791243, 0.45177541825604034, 'vw'),
#   Text(0.4915952954602606, 0.9840396666198672, 'ford'),
#   Text(-0.06392734957794274, 1.098140835219208, 'mercedes'),
#   Text(-0.58938029929197, 0.9287792325448002, 'audi'),
#   Text(-0.9280375179695062, 0.5905475131105022, 'peugeot'),
#   Text(-1.0799088491589592, 0.20927703531007047, 'bmw'),
#   Text(-1.0859247206969243, -0.17540667313220218, 'renault'),
#   Text(-0.9807733928794458, -0.49807986490094186, 'citroën'),
#   Text(-0.8073585825937295, -0.7471091748280464, 'skoda'),
#   Text(-0.5819171838304618, -0.9334732942954633, 'opel'),
#   Text(-0.334159107370012, -1.0480160738088309, 'toyota'),
#   Text(-0.09737331270054027, -1.0956817229349602, 'kia'),
#   Text(0.12334500207120871, -1.0930626745361192, 'hyundai'),
#   Text(0.333170774952274, -1.0483306895811557, 'volvo'),
#   Text(0.5045426935869374, -0.9774644087372379, 'nissan'),
#   Text(0.6381436915054219, -0.895975797101592, 'seat'),
#   Text(0.7580778135721494, -0.7970683964188203, 'fiat'),
#   Text(0.8619052988403805, -0.683461232134548, 'suzuki'),
#   Text(0.9423246280137068, -0.567471845503219, 'mazda'),
#   Text(0.9895391524750539, -0.4804292515230023, 'porsche'),
#   Text(1.0154551976157358, -0.42290748590582666, 'honda'),
#   Text(1.0345524379134514, -0.3737663082827748, 'dacia'),
#   Text(1.0495281422073792, -0.32937923236708044, 'chevrolet'),
#   Text(1.0614748244955532, -0.2885674911734427, 'land'),
#   Text(1.0709736288393532, -0.2510288555737511, 'mitsubishi'),
#   Text(1.0788427267928353, -0.21470531163946457, 'tesla'),
#   Text(1.0850572796827478, -0.1806950464386768, 'mini'),
#   Text(1.0895921998257212, -0.15095972336668345, 'jaguar'),
#   Text(1.0929263242479492, -0.12454737960257081, 'iveco'),
#   Text(1.0950806721694106, -0.10391497216952013, 'alfa'),
#   Text(1.096243694589586, -0.09082820086611247, 'smart'),
#   Text(1.0970514096762423, -0.08048729419833969, 'saab'),
#   Text(1.0976949550167194, -0.07117433337125462, 'ds'),
#   Text(1.0982203414243672, -0.06254663605459998, 'subaru'),
#   Text(1.0986092627319668, -0.05529636370978027, 'maxus'),
#   Text(1.0988968012451719, -0.04925261630745381, 'jeep'),
#   Text(1.0991168004027967, -0.04407106842724538, 'chrysler'),
#   Text(1.099281469861402, -0.03975235866405793, 'maserati'),
#   Text(1.099423587906749, -0.03560581910658202, 'bürstner'),
#   Text(1.0995401227507382, -0.031804378020830255, 'dodge'),
#   Text(1.0996301888015418, -0.028521007630969125, 'ferrari'),
#   Text(1.0997024634540729, -0.025583038776577777, 'aston'),
#   Text(1.099763316106433, -0.02281772439534586, 'bentley'),
#   Text(1.099814050142333, -0.020225110865404957, 'abarth'),
#   Text(1.0998530758065908, -0.01797808773984693, 'mg'),
#   Text(1.0998850247603318, -0.015903845697326526, '-'),
#   Text(1.0999086606632276, -0.014175267123579931, 'lamborghini'),
#   Text(1.099925613413848, -0.012792378831569452, 'daewoo'),
#   Text(1.0999408274934852, -0.011409470318428854, 'ssangyong'),
#   Text(1.0999543028780903, -0.010026543770146916, 'isuzu'),
#   Text(1.0999646675494374, -0.008816469977015896, 'gmc'),
#   Text(1.0999724920135199, -0.007779255335022043, 'cupra'),
#   Text(1.0999793384334828, -0.006742033776078003, 'triumph'),
#   Text(1.099985206803239, -0.005704806222432702, 'alpina'),
#   Text(1.099990097117571, -0.004667573596339416, 'morris'),
#   Text(1.0999934252507082, -0.003803209856792677, 'morgan'),
#   Text(1.0999955987259447, -0.00311171713866101, 'cadillac'),
#   Text(1.0999973375057355, -0.002420223190843271, 'rover'),
#   Text(1.0999986415893936, -0.0017287282866025478, 'lancia'),
#   Text(1.099999510976404, -0.0010372326992052388, 'lexus'),
#   Text(1.0999999456664227, -0.0003457367019150805, 'roller')])

# %%
re = requests.get('http://localhost:5000/api/pricemiles')
df = pd.read_json(re.text)
#Make all non-numeric entries to NaN.
numbersOnlyPrice = pd.to_numeric(df.iloc[1], errors='coerce')
numbersOnlyMiles = pd.to_numeric(df.iloc[0], errors='coerce')

plt.scatter(numbersOnlyMiles, numbersOnlyPrice)
plt.show()
# Out:
# 0       14700.0
# 1           NaN
# 2      169700.0
# 3        2495.0
# 4       69800.0
#          ...
# 495     84900.0
# 496     74900.0
# 497     14000.0
# 498     78888.0
# 499    134900.0
# Name: Pris, Length: 500, dtype: float64

# %%
re = requests.get('http://localhost:5000/api/pricemiles/make?make=audi')
df = pd.read_json(re.text)
#df[df.id.apply(lambda x: x.isnumeric())]
#Make all non-numeric entries to NaN.
numbersOnlyPrice = pd.to_numeric(df.iloc[1], errors='coerce')
numbersOnlyMiles = pd.to_numeric(df.iloc[0], errors='coerce')

plt.scatter(numbersOnlyMiles, numbersOnlyPrice)
plt.show()
# Out:
# 0       29400.0
# 1      239900.0
# 2      275000.0
# 3      489900.0
# 4      174850.0
#          ...
# 495    264700.0
# 496      4987.0
# 497    169900.0
# 498    789800.0
# 499         NaN
# Name: Pris, Length: 500, dtype: float64
